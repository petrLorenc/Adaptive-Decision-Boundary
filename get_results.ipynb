# %%
with open("results/results_banking.txt") as f:
    data = f.readlines()

# %%
data = [dict([p.split('=') for p in line.strip().split(";")]) for line in data]

# %%
data_mapping = {f'{d["Type"]}-{d["known_ratio"]}': d for d in data}

# %%
chosen_ratio = str(0.25)
chosen_types = ["use_dan", "use_tran", "sbert"]
metric = 'accuracy'
print(f"{data_mapping[chosen_types[0] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[1] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[2] + '-' + chosen_ratio][metric]}", end="")
print("\t", end="")

metric = 'f1'
print(f"{data_mapping[chosen_types[0] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[1] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[2] + '-' + chosen_ratio][metric]}", end="")
print("\t", end="")

metric = 'time_train'
print(f"{data_mapping[chosen_types[0] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[1] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[2] + '-' + chosen_ratio][metric]}", end="")
print("\t", end="")

metric = 'time_inference'
print(f"{data_mapping[chosen_types[0] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[1] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[2] + '-' + chosen_ratio][metric]}", end="")
print("\t", end="")

metric = 'memory'
print(f"{data_mapping[chosen_types[0] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[1] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[2] + '-' + chosen_ratio][metric]}", end="")
print("\t", end="")

metric = 'time_pretraining'
print(f"{data_mapping[chosen_types[0] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[1] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[2] + '-' + chosen_ratio][metric]}", end="")
print("\t", end="")

chosen_ratio = str(0.50)
metric = 'accuracy'
print(f"{data_mapping[chosen_types[0] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[1] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[2] + '-' + chosen_ratio][metric]}", end="")
print("\t", end="")

metric = 'f1'
print(f"{data_mapping[chosen_types[0] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[1] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[2] + '-' + chosen_ratio][metric]}", end="")
print("\t", end="")

metric = 'time_train'
print(f"{data_mapping[chosen_types[0] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[1] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[2] + '-' + chosen_ratio][metric]}", end="")
print("\t", end="")

metric = 'time_inference'
print(f"{data_mapping[chosen_types[0] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[1] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[2] + '-' + chosen_ratio][metric]}", end="")
print("\t", end="")

metric = 'memory'
print(f"{data_mapping[chosen_types[0] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[1] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[2] + '-' + chosen_ratio][metric]}", end="")
print("\t", end="")

metric = 'time_pretraining'
print(f"{data_mapping[chosen_types[0] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[1] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[2] + '-' + chosen_ratio][metric]}", end="")
print("\t", end="")

chosen_ratio = str(0.75)
metric = 'accuracy'
print(f"{data_mapping[chosen_types[0] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[1] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[2] + '-' + chosen_ratio][metric]}", end="")
print("\t", end="")

metric = 'f1'
print(f"{data_mapping[chosen_types[0] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[1] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[2] + '-' + chosen_ratio][metric]}", end="")
print("\t", end="")

metric = 'time_train'
print(f"{data_mapping[chosen_types[0] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[1] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[2] + '-' + chosen_ratio][metric]}", end="")
print("\t", end="")

metric = 'time_inference'
print(f"{data_mapping[chosen_types[0] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[1] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[2] + '-' + chosen_ratio][metric]}", end="")
print("\t", end="")

metric = 'memory'
print(f"{data_mapping[chosen_types[0] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[1] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[2] + '-' + chosen_ratio][metric]}", end="")
print("\t", end="")

metric = 'time_pretraining'
print(f"{data_mapping[chosen_types[0] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[1] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[2] + '-' + chosen_ratio][metric]}", end="")
print("\t", end="")
# Out:
# 77.0 / 80.0 / 72.0	65.6 / 68.7 / 60.7	1.2 / 18.4 / 23.2	1.0 / 15.2 / 28.4	2446.9 / 3659.6 / 3551.6	0 / 0 / 0	68.7 / 73.0 / 64.1	70.3 / 74.0 / 64.5	3.4 / 34.6 / 47.6	1.6 / 15.2 / 28.6	5489.4 / 5078.8 / 5626.1	0 / 0 / 0	68.2 / 71.7 / 63.6	74.9 / 78.0 / 70.3	5.7 / 56.0 / 72.8	1.9 / 17.6 / 30.2	6720.5 / 6594.7 / 6825.0	0 / 0 / 0

# %%
chosen_ratio = str(0.25)
chosen_types = ["use_dan_cosface", "use_tran_cosface", "sbert_cosface"]
metric = 'accuracy'
print(f"{data_mapping[chosen_types[0] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[1] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[2] + '-' + chosen_ratio][metric]}", end="")
print("\t", end="")

metric = 'f1'
print(f"{data_mapping[chosen_types[0] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[1] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[2] + '-' + chosen_ratio][metric]}", end="")
print("\t", end="")

metric = 'time_train'
print(f"{data_mapping[chosen_types[0] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[1] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[2] + '-' + chosen_ratio][metric]}", end="")
print("\t", end="")

metric = 'time_inference'
print(f"{data_mapping[chosen_types[0] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[1] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[2] + '-' + chosen_ratio][metric]}", end="")
print("\t", end="")

metric = 'memory'
print(f"{data_mapping[chosen_types[0] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[1] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[2] + '-' + chosen_ratio][metric]}", end="")
print("\t", end="")

metric = 'time_pretraining'
print(f"{data_mapping[chosen_types[0] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[1] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[2] + '-' + chosen_ratio][metric]}", end="")
print("\t", end="")

chosen_ratio = str(0.50)
metric = 'accuracy'
print(f"{data_mapping[chosen_types[0] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[1] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[2] + '-' + chosen_ratio][metric]}", end="")
print("\t", end="")

metric = 'f1'
print(f"{data_mapping[chosen_types[0] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[1] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[2] + '-' + chosen_ratio][metric]}", end="")
print("\t", end="")

metric = 'time_train'
print(f"{data_mapping[chosen_types[0] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[1] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[2] + '-' + chosen_ratio][metric]}", end="")
print("\t", end="")

metric = 'time_inference'
print(f"{data_mapping[chosen_types[0] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[1] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[2] + '-' + chosen_ratio][metric]}", end="")
print("\t", end="")

metric = 'memory'
print(f"{data_mapping[chosen_types[0] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[1] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[2] + '-' + chosen_ratio][metric]}", end="")
print("\t", end="")

metric = 'time_pretraining'
print(f"{data_mapping[chosen_types[0] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[1] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[2] + '-' + chosen_ratio][metric]}", end="")
print("\t", end="")

chosen_ratio = str(0.75)
metric = 'accuracy'
print(f"{data_mapping[chosen_types[0] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[1] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[2] + '-' + chosen_ratio][metric]}", end="")
print("\t", end="")

metric = 'f1'
print(f"{data_mapping[chosen_types[0] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[1] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[2] + '-' + chosen_ratio][metric]}", end="")
print("\t", end="")

metric = 'time_train'
print(f"{data_mapping[chosen_types[0] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[1] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[2] + '-' + chosen_ratio][metric]}", end="")
print("\t", end="")

metric = 'time_inference'
print(f"{data_mapping[chosen_types[0] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[1] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[2] + '-' + chosen_ratio][metric]}", end="")
print("\t", end="")

metric = 'memory'
print(f"{data_mapping[chosen_types[0] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[1] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[2] + '-' + chosen_ratio][metric]}", end="")
print("\t", end="")

metric = 'time_pretraining'
print(f"{data_mapping[chosen_types[0] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[1] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[2] + '-' + chosen_ratio][metric]}", end="")
print("\t", end="")
# Out:
# 85.6 / 85.6 / 85.1	77.6 / 78.4 / 77.2	1.2 / 8.7 / 38.0	1.5 / 9.7 / 46.7	4136.7 / 4465.7 / 5520.3	6.9 / 27.4 / 33.9	81.5 / 84.5 / 81.5	82.1 / 85.2 / 82.0	3.1 / 16.6 / 81.0	2.0 / 11.0 / 48.5	5764.0 / 5717.8 / 6236.5	15.6 / 51.8 / 68.6	81.6 / 83.5 / 81.5	86.6 / 88.0 / 86.3	5.2 / 26.8 / 132.8	2.1 / 10.9 / 51.0	7093.8 / 7226.2 / 8205.0	19.9 / 71.9 / 105.2

# %%
chosen_ratio = str(0.25)
chosen_types = ["use_dan_triplet_loss", "use_tran_triplet_loss", "sbert_triplet_loss"]
metric = 'accuracy'
print(f"{data_mapping[chosen_types[0] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[1] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[2] + '-' + chosen_ratio][metric]}", end="")
print("\t", end="")

metric = 'f1'
print(f"{data_mapping[chosen_types[0] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[1] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[2] + '-' + chosen_ratio][metric]}", end="")
print("\t", end="")

metric = 'time_train'
print(f"{data_mapping[chosen_types[0] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[1] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[2] + '-' + chosen_ratio][metric]}", end="")
print("\t", end="")

metric = 'time_inference'
print(f"{data_mapping[chosen_types[0] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[1] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[2] + '-' + chosen_ratio][metric]}", end="")
print("\t", end="")

metric = 'memory'
print(f"{data_mapping[chosen_types[0] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[1] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[2] + '-' + chosen_ratio][metric]}", end="")
print("\t", end="")

metric = 'time_pretraining'
print(f"{data_mapping[chosen_types[0] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[1] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[2] + '-' + chosen_ratio][metric]}", end="")
print("\t", end="")

chosen_ratio = str(0.50)
metric = 'accuracy'
print(f"{data_mapping[chosen_types[0] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[1] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[2] + '-' + chosen_ratio][metric]}", end="")
print("\t", end="")

metric = 'f1'
print(f"{data_mapping[chosen_types[0] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[1] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[2] + '-' + chosen_ratio][metric]}", end="")
print("\t", end="")

metric = 'time_train'
print(f"{data_mapping[chosen_types[0] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[1] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[2] + '-' + chosen_ratio][metric]}", end="")
print("\t", end="")

metric = 'time_inference'
print(f"{data_mapping[chosen_types[0] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[1] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[2] + '-' + chosen_ratio][metric]}", end="")
print("\t", end="")

metric = 'memory'
print(f"{data_mapping[chosen_types[0] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[1] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[2] + '-' + chosen_ratio][metric]}", end="")
print("\t", end="")

metric = 'time_pretraining'
print(f"{data_mapping[chosen_types[0] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[1] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[2] + '-' + chosen_ratio][metric]}", end="")
print("\t", end="")

chosen_ratio = str(0.75)
metric = 'accuracy'
print(f"{data_mapping[chosen_types[0] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[1] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[2] + '-' + chosen_ratio][metric]}", end="")
print("\t", end="")

metric = 'f1'
print(f"{data_mapping[chosen_types[0] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[1] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[2] + '-' + chosen_ratio][metric]}", end="")
print("\t", end="")

metric = 'time_train'
print(f"{data_mapping[chosen_types[0] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[1] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[2] + '-' + chosen_ratio][metric]}", end="")
print("\t", end="")

metric = 'time_inference'
print(f"{data_mapping[chosen_types[0] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[1] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[2] + '-' + chosen_ratio][metric]}", end="")
print("\t", end="")

metric = 'memory'
print(f"{data_mapping[chosen_types[0] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[1] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[2] + '-' + chosen_ratio][metric]}", end="")
print("\t", end="")

metric = 'time_pretraining'
print(f"{data_mapping[chosen_types[0] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[1] + '-' + chosen_ratio][metric]} / {data_mapping[chosen_types[2] + '-' + chosen_ratio][metric]}", end="")
print("\t", end="")
# Out:
# 81.9 / 83.5 / 83.4	67.4 / 76.1 / 75.0	1.5 / 7.4 / 42.7	1.8 / 9.6 / 49.3	4374.1 / 4757.6 / 5189.2	31.3 / 48.2 / 57.4	79.7 / 81.8 / 77.3	80.8 / 83.3 / 73.2	2.9 / 17.6 / 81.8	1.9 / 10.4 / 48.3	5628.7 / 6055.1 / 6410.1	56.5 / 90.4 / 113.4	73.5 / 81.4 / 80.2	75.8 / 86.5 / 85.0	6.2 / 26.2 / 119.8	2.2 / 9.9 / 47.8	7177.4 / 7618.8 / 7696.6	93.3 / 141.4 / 165.0
